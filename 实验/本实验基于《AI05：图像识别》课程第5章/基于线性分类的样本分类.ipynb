# %%
import pandas as pd
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt
import tensorflow as tf
# Out:
# E:\Anaconder3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
train_data = pd.read_csv(r'MoonDataTrain.csv')
test_data = pd.read_csv(r'MoonDataTest.csv')
train_data.head()
plt.scatter(train_data.x1,train_data.x2,c=train_data.y,cmap=plt.cm.Spectral)
plt.show()

# %%
X = tf.placeholder(dtype=tf.float32,shape=(None,2),name="samples")
y_ = tf.placeholder(dtype=tf.float32,shape=(None,2),name='labels')
W = tf.Variable(tf.zeros(2,2),name="weight")
b = tf.Variable(tf.zeros(2),name="bias")
pred = tf.nn.softmax(tf.multiply(x,W)+b,name"pred)
learning_rate = 0.001
training_epoch = 20000
# Out:
# array([0.16755964, 1.94900108, 1.81741304, 3.00199685, 0.75010991,
#        2.79692692, 2.73656682, 2.4104217 , 1.44244422, 3.0729625 ])
